# %% [markdown]
# <a href="https://colab.research.google.com/github/louissssssssssss/Introduction-to-computers/blob/main/0330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('100')
# Out:
# 100

# %%
not(3>5)
# Out:
# True

# %%
not(5>3)
# Out:
# False

# %%
(5>3)and(9>6)
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(5>3)and(9<6)
# Out:
# False

# %%
(5<3)and(9>6)
# Out:
# False

# %%
(5<3)and(9<6)
# Out:
# False

# %%
(5>3)or(9>6)
# Out:
# True

# %%
(5>3)or(9<6)
# Out:
# True

# %%
(5<3)or(9>6)
# Out:
# True

# %%
(5<3)or(9<6)
# Out:
# False

# %%
A=1

# %%
i=10

# %%
i+=5

# %%
i
# Out:
# 15

# %%
i-=5

# %%
i
# Out:
# 10

# %%
i=10
i*=5

# %%
i
# Out:
# 50

# %%
print(1+2)
# Out:
# 3

# %%
print('1'+'2')
# Out:
# 12

# %%
print(('你'+"好"+"!"))
# Out:
# 你好!

# %%
i=int(input('請輸入本金存款金額:'))
years=1.02**6
i*=years
print('六年後存款為:'+str(i))
# Out:
# 請輸入本金存款金額:10000
# 六年後存款為:11261.62419264

# %%
pw=input('請輸入密碼')
if(pw=='1234'):
     print('歡迎光臨!')
# Out:
# 請輸入密碼123

# %%
i=input('今天會下雨嗎?')
if(i=='y' or i=='Y'): 
    print('出門記得帶傘!')
# Out:
# 今天會下雨嗎?Y
# 出門記得帶傘!

# %%
pw=input('請輸入密碼')
if(pw=='1234'):
    print('歡迎光臨!')
else:
    print('密碼錯誤')
# Out:
# 請輸入密碼1234
# 歡迎光臨!

# %%
i=input('今天會下雨嗎?')
if(i=='y' or i=='Y'): 
    print('出門記得帶傘!')
else:
    print('不用帶傘!')
# Out:
# 今天會下雨嗎?n
# 不用帶傘!

# %%
i=int(input('請輸入正整數:'))
if(i%2)==0:
    print(i,'為偶數!')
else:
    print(i,"為奇數!")
# Out:
# 請輸入正整數:30
# 30 為偶數!

# %%
i=int(input('請輸入正整數:'))
if(i%2)==0:
    print(i,'為偶數!')
else:
    print(i,"為奇數!")
# Out:
# 請輸入正整數:31
# 31 為奇數!
